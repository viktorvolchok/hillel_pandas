# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('workers_csv.csv')
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>name</th>
#       <th>age</th>
#       <th>position</th>
#       <th>salary</th>
#       <th>length_of_service</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>William</td>
#       <td>50</td>
#       <td>Pension scheme manager</td>
#       <td>5213</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Melissa</td>
#       <td>25</td>
#       <td>Clinical research associate</td>
#       <td>6969</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...

# %%
df['salary'].mean()
# Out:
# 4739.9

# %%
df['age'].max()
# Out:
# 54

# %%
df.dropna ()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>name</th>
#       <th>age</th>
#       <th>position</th>
#       <th>salary</th>
#       <th>length_of_service</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>William</td>
#       <td>50</td>
#       <td>Pension scheme manager</td>
#       <td>5213</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Melissa</td>
#       <td>25</td>
#       <td>Clinical research associate</td>
#       <td>6969</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...

# %%
df[~(df['salary'] < 0)]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>name</th>
#       <th>age</th>
#       <th>position</th>
#       <th>salary</th>
#       <th>length_of_service</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>William</td>
#       <td>50</td>
#       <td>Pension scheme manager</td>
#       <td>5213</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Melissa</td>
#       <td>25</td>
#       <td>Clinical research associate</td>
#       <td>6969</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...

# %%
pd.pivot_table(df, values='salary', index='position', columns='age', aggfunc='mean')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>age</th>
#       <th>18</th>
#       <th>19</th>
#       <th>20</th>
#       <th>21</th>
#       <th>23</th>
#       <th>24</th>
#       <th>25</th>
#       <th>26</th>
#       <th>27</th>
#       <th>28</th>
#       <th>...</th>
#       <th>39</th>
#       <th>40</th>
#       <th>41</th>
#       <th>42</th>
#       <th>46</th>
#       <th>47</th>
#       <th>48</th>
#       <th>50</th>
#       <th>52</th>
#       <th>54</th>
#     </tr>
#     <tr>
#       <th>position</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
plt.plot(df['age'], df['salary'], 'o-')
plt.xlabel('age')
plt.ylabel('salary')
plt.title('Dependence of salary on the age of workers')
plt.grid(True)
plt.show()
